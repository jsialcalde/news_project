# %% [markdown]
# # Project Title: The Impact of News on the Market
# ### •	Team Members:
# ##### 	Rachel Torres, Christian Attard, Jess Alcalde, Nitin Khade
# ### •	Project Description/Outline:
# ##### -	We will look at news data and stock data to determine the effects of the news on how the market behaves.
# ### •	Research Questions to Answer:
# ##### -	How do news headlines affect the stock market?
# ##### -	Is there any correlation between certain types of headlines and effects on the market?
# ##### -	Does negative news affect stocks greater than positive or neutral?
# ##### -	Can we assign a factor(weighting) to it?

# %%
# import dependencies
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint

from news_api import api_key
from x_api import x_api_key

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# pip install vaderSentiment

# %% [markdown]
# ### We'll query the news api to gather news headlines from the web

# %%
# parameters for news api
q='politics',
from_param='2019-05-24',
language='en',
sort_by='relevancy',
page = 4,
pageSize = 50

url = f'https://newsapi.org/v2/everything?q={q}&from={from_param}&language={language}&sortBy={sort_by}&pageSize={pageSize}&page={page}&apiKey={api_key}'
response = requests.get(url)

url_2 = f'https://newsapi.org/v2/everything?q=apple&from=2019-05-24&to=2019-06-23&language=en&sortBy=popularity&pageSize={pageSize}&page=3&apiKey={api_key}'
response = requests.get(url_2)
# Generate response into json

# %%
pprint(response.json())
# Out:
# {'code': 'parameterInvalid',
#  'message': 'You are trying to request results too far in the past. Your plan '
#             'permits you to request articles as far back as 2019-05-26, but '
#             'you have requested 2019-05-24. To extend this please upgrade to a '
#             'paid plan.',
#  'status': 'error'}

# %% [markdown]
# ### We'll use a different API to gather news data since we have a restriction on the news api

# %%
# Query contextual web search API
# Replace the following string value with your valid X-RapidAPI-Key.
Your_X_RapidAPI_Key = x_api_key;

# The query parameters: (update according to your search query)
q = "Wayfair" #the search query
pageNumber = 1 #the number of requested page
pageSize = 50 #the size of a page
autoCorrect = True #autoCorrectspelling
safeSearch = False #filter results for adult content


# test response to query and get count of total items and pages
response_test=requests.get("https://contextualwebsearch-websearch-v1.p.rapidapi.com/api/Search/NewsSearchAPI?q={}&pageNumber={}&pageSize={}&autocorrect={}&safeSearch={}".format(q, pageNumber, pageSize, autoCorrect,safeSearch),
headers={
"X-RapidAPI-Key": Your_X_RapidAPI_Key
}
).json()

#Get the number of items returned
totalCount = response_test["totalCount"];
totalPages = round(totalCount/pageSize)

# %%
# generate sample response to look at headers
pprint((response_test['value'][2]))
# Out:
# {'datePublished': '2019-06-26T23:21:56',
#  'description': 'Employees at online home furnishings retailer <b>Wayfair</b> '
#                 'walked out Wednesday to protest the companys decision to sell '
#                 '$200,000 worth of furniture to a government contractor that '
#                 'runs a detenti',
#  'image': {'base64Encoding': None,
#            'height': 545,
#            'thumbnail': 'https://contextualwebsearch.com/api/thumbnail/get?value=8699078739924360482',
#            'thumbnailHeight': 102,
#            'thumbnailWidth': 191,
#            'url': 'https://www.twincities.com/wp-content/uploads/2019/06/AP19177652939088.jpg?w=1024&amp;h=545',
#            'width': 1024},
#  'isSafe': True,
#  'keywords': 'detention center,twin cities,wayfair,protest',
#  'language': 'en',
#  'provider': {'name': 'twincities'},
#  'title': '<b>Wayfair</b> workers walk out in protest over furniture sale to '
#           'detention center  Twin Cities',
#  'url': 'https://www.twincities.com/2019/06/26/wayfair-workers-protest-contract-with-detention-center/'}

# %%
print(f' There are {totalPages} pages, with {totalCount} total articles.')
# Out:
#  There are 30 pages, with 1481 total articles.

# %%
# create empty lists to hold variable results
url_list = []
title_list = []
description_list = []
keywords_list = []
provider_list = []
date_list = []

# Load news data into pandas dataframe
# page = 1
for page in range(1,totalPages+1):
    response=requests.get("https://contextualwebsearch-websearch-v1.p.rapidapi.com/api/Search/NewsSearchAPI?q={}&pageNumber={}&pageSize={}&autocorrect={}&safeSearch={}".format(q, page, pageSize, autoCorrect,safeSearch),
headers={"X-RapidAPI-Key": Your_X_RapidAPI_Key}).json()

# print(response)
    try:
        #Go over each resulting item
        for webPage in response["value"]:

#Get the web page metadata
            url = webPage["url"]
            title = webPage["title"]
            description = webPage["description"]
            keywords = webPage["keywords"]
            provider = webPage["provider"]["name"]
            datePublished = webPage["datePublished"]
        
        
            url_list.append(url)
            title_list.append(title)
            description_list.append(description)
            keywords_list.append(keywords)
            provider_list.append(provider)
            date_list.append(datePublished)

#             print(f'printing {title}')    
    except (KeyError,IndexError):
            print('Not found, skipping')

# %%
# assign list to dataframe

newsFrame = pd.DataFrame({'datePublished':date_list,'description':description_list,'keywords':keywords_list,'provider':provider_list,'title':title_list,'url':url_list})

# %%
newsFrame.head(200)
# Out:
#            datePublished                                        description  \
# 0    2019-06-27T01:23:00  Bank of America Corp.  the USs second largest ...
# 1    2019-06-27T00:34:06  Employees said the donation was not enough and...
# 2    2019-06-26T23:21:56  Employees at online home furnishings retailer ...
# 3    2019-06-26T22:44:42  Employees of American online furniture store <...
# 4    2019-06-26T22:09:15  Some Wayfairemployees walked off the job to pr...
# 5    2019-06-26T22:04:39  Catch up on the most important news from today...
# 6    2019-06-26T22:01:07  Hundreds of employees at Boston-based online f...
# 7    2019-06-26T21:49:10  BOSTON (AP)  Employees at online home furnishi...
# 8    2019-06-26T21:37:39  The protest triggered a broader backlash again...
# 9    2019-06-26T21:25:52  The Latest on a protest by <b>Wayfair</b> empl...
# 10   2019-06-26T21:25:38  "We know that theres injustice in this world, ...
# 11   2019-06-26T21:20:22  Employees want the company to stop selling fur...
# 12   2019-06-26T21:01:50  Hundreds of <b>Wayfair</b> employees filled Co...
# 13   2019-06-26T20:57:54  BOSTON  The Latest on a protest by <b>Wayfair<...
# 14   2019-06-26T20:34:52  Several hundred people, including employees of...
# 15   2019-06-26T20:30:29  A discussion about the walkout and whether <b>...
# 16   2019-06-26T20:03:32  Employees at online home furnishings retailer ...
# 17   2019-06-26T19:58:46  Employees and consumers, with the help of acti...
# 18   2019-06-26T19:43:55  An estimated "hundreds" of <b>Wayfair</b> ([[W...
# 19   2019-06-26T19:30:00  On Tuesday, <b>Wayfair</b> employees announced...
# 20   2019-06-26T19:15:41  Employees at online home furnishings retailer ...
# 21   2019-06-26T19:13:00  Online home goods retailer <b>Wayfair</b> sold...
# 22   2019-06-26T19:11:36  We dont want to profit off these detention cen...
# 23   2019-06-26T19:02:32  Hundreds of <b>Wayfair</b> employees walked of...
# 24   2019-06-26T18:54:32  Hundreds of staff in Boston are protesting ove...
# 25   2019-06-26T18:52:37  <b>Wayfair</b> workers walk out to protest U.S...
# 26   2019-06-26T18:50:58  <b>Wayfair</b> employees and other demonstrato...
# 8         wayfair workers protest sale,lakeland,ledger              theledger
# 9                                 wayfair,latest,texas            startribune
# 10      president donald trumps,wayfair walkout,boston                 boston
# 11       getty images wayfair,wayfair employees,border                 google
# 12       wayfair protest,maine public,brunswick,boston            mainepublic
# 13                   protest sale,wayfair,latest,texas           citynews1130
# 14               protest furniture sale,wayfair,boston                reuters
# 15                  copley square,radio boston,wayfair                   wbur
# 16         detention center,protest sale,wayfair,texas                newsmax
# 17     wayfair workers walk,consumer boycott,employees                nytimes
# 18                  join protest,wayfair,boston,copley           seekingalpha
# 19                  wayfair,walkout,company,camps,read                gizmodo
# 20          spokesman review,detention,wayfair,protest              spokesman
# 21                stock exchange,services,wayfair,beds                   cnbc
# 22   leave work in protest over border camp furnish...                thestar
# 23   migrant children,baptist children,services,way...                 nbcdfw
# 24             wayfair staff,detention,hundreds,report                    bbc
# 25   embed wayfair workers walk out,published,duration            onenewspage
# 26   sales to migrant detention,wayfair employees,w...               usatoday
# 27             portland press herald,brunswick,wayfair            pressherald
# 28   air employees stage walkout,migrant detention,...                foxnews
# 29      getty images employees,wayfair employees,texas                 nypost
# ..                                                 ...                    ...
# 170  best 25 beautful dresses deas on pnterest pret...       rachelskitchennz
# 171  moonlight slumber little star organic crib,way...               elvellon
# 172           bed headboard from two,wayfair headboard                  110am
# 173   communities,gift card,community,edmonton,wayfair                livemlc
# 174  wayfair in christmas decoration christmas,rese...      researchpaperspot
# 175                                      wayfair apply            eisneramper
# 176                      children,reviews,wayfair,site     aerconditionatauto
# 177  states still responding,2019 outlook,wayfair,s...              netchoice
# 178          gold by u by wayfair havenly,inspect home     inspectatlantahome
# 179                   wayfair furniture sectional,home            lalati-fiji
# 180                 details company,pittsfield,wayfair     publicbroadcasting
# 181                     new furniture,new year,wayfair       howtoshopforfree
# 182  living room designed by wayfair via,adrevenue0...            adrevenue08
# 183                         vase ideas,wayfair,ceramic         emkenforsenate
# 184               wayfair kitchen and dining,selecting           sodakaustica
# 185                           davinci wayfair,dog beds         brushportfolio
# 186                 comforter set in coralgrey,wayfair              brstylers
# 187                   my favorite wayfair bathroom,cue            organized31
# 188        financial institutions,south dakota,wayfair              mossadams
# 189  entryway wall organizer inspirational gracie o...  facts-about-recycling
# 190  cheap pre lit christmas,getforum.net,wayfair,love               getforum
# 191  beachcrest home newtown 60 double bathroom van...             emaudesign
# 192                                 wayfair,daily,home                    nme
# 193           darby home co aron,reviews,wayfair,ideas        worksheetgarden
# 194                         reviews,wayfair,ideas,home          therealityera
# 195               black torchiere,way way,aquaria,lamp             theaquaria
# 196                            000 jobs,wayfair,boston               masslive
# 197  bird dog bay neck tie,bird dog bay wayfair,nec...        countryclubprep
# 198                 merced sun star,california,wayfair          mercedsunstar
# 199                             wayfair sale,day deals             refinery29
#
#                                                  title  \
# 0    Bank of America, <b>Wayfair</b>, Join those Sa...
# 1    <b>Wayfair</b> employees walk out; company mak...
# 2    <b>Wayfair</b> workers walk out in protest ove...
# 3    <b>Wayfair</b> staff strike over migrant cente...
# 4    <b>Wayfair</b> employees stage walkout to prot...
# 5    <b>Wayfair</b> Walkout, Facebook Data Value, a...
# 199  https://www.refinery29.com/en-us/wayfair-sale-...
#
# [200 rows x 6 columns]

# %%
newsFrame.dtypes
# Out:
# datePublished    object
# description      object
# keywords         object
# provider         object
# title            object
# url              object
# dtype: object

# %%
# clean description and title columns
newsFrame.description = newsFrame.description.str.replace('<b>','')
newsFrame.description = newsFrame.description.str.replace('</b>','')
newsFrame.title = newsFrame.title.str.replace('<b>','')
newsFrame.title = newsFrame.title.str.replace('</b>','')

# %%
newsFrame.head()
# Out:
#          datePublished                                        description  \
# 0  2019-06-27T01:23:00  Bank of America Corp.  the USs second largest ...
# 1  2019-06-27T00:34:06  Employees said the donation was not enough and...
# 2  2019-06-26T23:21:56  Employees at online home furnishings retailer ...
# 3  2019-06-26T22:44:42  Employees of American online furniture store W...
# 4  2019-06-26T22:09:15  Some Wayfairemployees walked off the job to pr...
#
#                                             keywords     provider  \
# 0  bank of america corp,join those saying,detenti...       forbes
# 1        wayfair employees walk out,donation,company  mercurynews
# 2       detention center,twin cities,wayfair,protest   twincities
# 3  migrant centers contract,employees,american,wa...    dailymail
# 4  wayfair employees stage walkout,border camps,p...        adage
#
#                                                title  \
# 0  Bank of America, Wayfair, Join those Saying "N...
# 1  Wayfair employees walk out; company makes $100...
# 2  Wayfair workers walk out in protest over furni...
# 3  Wayfair staff strike over migrant centers cont...
# 4  Wayfair employees stage walkout to protest bed...
#
#                                                  url
# 0  https://www.forbes.com/sites/morgansimon/2019/...
# 1  https://www.mercurynews.com/2019/06/26/wayfair...
# 2  https://www.twincities.com/2019/06/26/wayfair-...
# 3  https://www.dailymail.co.uk/wires/afp/article-...
# 4  https://adage.com/article/news/wayfair-employe...

# %%
print(totalPages)
# Out:
# 30

# %%
newsFrame.count()
# Out:
# datePublished    855
# description      855
# keywords         855
# provider         855
# title            855
# url              855
# dtype: int64

# %%
# Query sample news description
newsFrame.iloc[7][1]
# Out:
# "BOSTON (AP)  Employees at online home furnishings retailer Wayfair walked out Wednesday to protest the company's decision to sell $200,000 worth of furniture to a government contractor that runs a detention center for migrant children in Texas."

# %%
# import stock data


# Load stock data into notebook as dataframe

# %%
# Merge 2 DataFrames

# %% [markdown]
# ### About the Scoring (taken from vaderSentiment docs)
# The compound score is computed by summing the valence scores of each word in the lexicon, adjusted according to the rules, and then normalized to be between -1 (most extreme negative) and +1 (most extreme positive). This is the most useful metric if you want a single unidimensional measure of sentiment for a given sentence. Calling it a 'normalized, weighted composite score' is accurate.
#
# It is also useful for researchers who would like to set standardized thresholds for classifying sentences as either positive, neutral, or negative. Typical threshold values (used in the literature cited on this page) are:
#
#     positive sentiment: compound score >= 0.05
#     neutral sentiment: (compound score > -0.05) and (compound score < 0.05)
#     negative sentiment: compound score <= -0.05
# The pos, neu, and neg scores are ratios for proportions of text that fall in each category (so these should all add up to be 1... or close to it with float operation). These are the most useful metrics if you want multidimensional measures of sentiment for a given sentence.

# %%
# Do sentiment analysis of news data

# Define function to test 
def sentiment_scores_print(sentence):
    score = analyser.polarity_scores(sentence)
    print("{:-<40} \n \n{}".format(sentence, str(score)))
    return score

def sentiment_scores(sentence):
    score = analyser.polarity_scores(sentence)
    return score

# Do test of single string
sentiment_scores_print(newsFrame.iloc[0][1])
# Out:
# Bank of America Corp.  the USs second largest financial institution and lead lender to CoreCivic  made a milestone announcement this morning that they will stop financing private prison and immigration-detention companies.
#
# {'neg': 0.164, 'neu': 0.836, 'pos': 0.0, 'compound': -0.6705}
# {'neg': 0.164, 'neu': 0.836, 'pos': 0.0, 'compound': -0.6705}

# %%
# add column in newsFrame for sentiment score
newsFrame['sentiment_score'] = ''
newsFrame['sentiment'] = ''

# %%
# check dataframe
newsFrame.head()
# Out:
#          datePublished                                        description  \
# 0  2019-06-27T01:23:00  Bank of America Corp.  the USs second largest ...
# 1  2019-06-27T00:34:06  Employees said the donation was not enough and...
# 2  2019-06-26T23:21:56  Employees at online home furnishings retailer ...
# 3  2019-06-26T22:44:42  Employees of American online furniture store W...
# 4  2019-06-26T22:09:15  Some Wayfairemployees walked off the job to pr...
#
#                                             keywords     provider  \
# 0  bank of america corp,join those saying,detenti...       forbes
# 1        wayfair employees walk out,donation,company  mercurynews
# 2       detention center,twin cities,wayfair,protest   twincities
# 3  migrant centers contract,employees,american,wa...    dailymail
# 4  wayfair employees stage walkout,border camps,p...        adage
#
#                                                title  \
# 0  Bank of America, Wayfair, Join those Saying "N...
# 1  Wayfair employees walk out; company makes $100...
# 2  Wayfair workers walk out in protest over furni...
# 3  Wayfair staff strike over migrant centers cont...
# 4  Wayfair employees stage walkout to protest bed...
#
#                                                  url sentiment_score sentiment
# 0  https://www.forbes.com/sites/morgansimon/2019/...
# 1  https://www.mercurynews.com/2019/06/26/wayfair...
# 2  https://www.twincities.com/2019/06/26/wayfair-...
# 3  https://www.dailymail.co.uk/wires/afp/article-...
# 4  https://adage.com/article/news/wayfair-employe...

# %%
# add in sentiment analysis to data frame

for i, row in newsFrame.iterrows():
    sentiment_score = float(sentiment_scores(row[1])['compound']) # take sentiment of description of each article
    if(sentiment_score >= 0.05):
        row['sentiment'] = 'positive'
    elif(sentiment_score <= 0.05):
        row['sentiment'] = 'negative'
    else:
        row['sentiment'] = 'neutral'
    row['sentiment_score'] = sentiment_score
#     print((sentiment_score))

# %%
# check dataframe to see if sentiment score was added in
newsFrame.head()
# Out:
#          datePublished                                        description  \
# 0  2019-06-27T01:23:00  Bank of America Corp.  the USs second largest ...
# 1  2019-06-27T00:34:06  Employees said the donation was not enough and...
# 2  2019-06-26T23:21:56  Employees at online home furnishings retailer ...
# 3  2019-06-26T22:44:42  Employees of American online furniture store W...
# 4  2019-06-26T22:09:15  Some Wayfairemployees walked off the job to pr...
#
#                                             keywords     provider  \
# 0  bank of america corp,join those saying,detenti...       forbes
# 1        wayfair employees walk out,donation,company  mercurynews
# 2       detention center,twin cities,wayfair,protest   twincities
# 3  migrant centers contract,employees,american,wa...    dailymail
# 4  wayfair employees stage walkout,border camps,p...        adage
#
#                                                title  \
# 0  Bank of America, Wayfair, Join those Saying "N...
# 1  Wayfair employees walk out; company makes $100...
# 2  Wayfair workers walk out in protest over furni...
# 3  Wayfair staff strike over migrant centers cont...
# 4  Wayfair employees stage walkout to protest bed...
#
#                                                  url sentiment_score sentiment
# 0  https://www.forbes.com/sites/morgansimon/2019/...         -0.6705  negative
# 1  https://www.mercurynews.com/2019/06/26/wayfair...         -0.0772  negative
# 2  https://www.twincities.com/2019/06/26/wayfair-...         -0.0258  negative
# 3  https://www.dailymail.co.uk/wires/afp/article-...         -0.0258  negative
# 4  https://adage.com/article/news/wayfair-employe...           -0.25  negative

# %%
# Use Matplotlib and stats to generate graphs and look for relationships
