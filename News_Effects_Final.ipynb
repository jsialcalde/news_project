# %% [markdown]
# # Project Title: The Impact of News on the Market
# ### •	Team Members:
# ##### 	Rachel Torres, Christian Attard, Jess Alcalde, Nitin Khade
# ### •	Project Description/Outline:
# ##### -	We will look at news data and stock data to determine the effects of the news on how the market behaves.
# ### •	Research Questions to Answer:
# ##### -	How do news headlines affect the stock market?
# ##### -	Is there any correlation between certain types of headlines and effects on the market?
# ##### -	Does negative news affect stocks greater than positive or neutral?
# ##### -	Can we assign a factor(weighting) to it?

# %%
# import dependencies
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint
import scipy.stats as sp
from news_api import api_key
from x_api import x_api_key

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# Rather than rewriting code multiple times, we've created a function to call the news API and output data into a dataframe
# preliminary work is in older notebook
from news_pull import sentiment_scores
from news_pull import news_pull

# %% [markdown]
# ### We'll query the news api to gather news headlines from the web

# %%
# Create newDF for general market (S&P & Nasdaq)
genNews = news_pull('News')
# Out:
# Please wait...searching
#  There are 27 pages, with 1369 total articles.
#   datePublished                                        description  \
# 0    06/30/2019  Quite a few new laws will be implemented in Ge...
# 1    06/28/2019  Watch New movies reviews: Yesterday, Euphoria ...
# 2    06/28/2019  Find and research the best new cars, get best ...
# 3    06/27/2019  International Business News: "Additional tarif...
# 4    06/26/2019  WALLENPAUPACK- Rain clouds past, sunshine retu...
#
#                                             keywords     provider  \
# 0   s will take effect july 1,new georgia laws,these  forsythnews
# 1                       new movie,yesterday,s videos   globalnews
# 2                  car reviews,roadshow,new car,cnet         cnet
# 3    on new tariffs,s on china,trump s,s news,donald   indiatimes
# 4  new chapter opens,s for wahs,s of 2019,s class...       neagle
#
#                                                title  \
# 0     These new Georgia laws will take effect July 1
# 1  New movies reviews: Yesterday, Euphoria and An...
# 2                  New cars, car reviews and pricing
# 3  Donald Trump says will decide on new tariffs o...
# 4           New chapter opens for WAHS Class of 2019
#
#                                                  url sentiment_score sentiment
# 0  https://www.forsythnews.com/local/state-govern...          0.4278  positive
# 1  https://globalnews.ca/video/5442628/new-movies...          0.6486  positive
# 2                      http://cnet.com/roadshow/auto          0.8555  positive
# 3  http://timesofindia.indiatimes.com/world/europ...          0.3094  positive
# 4  https://www.neagle.com/news/20190626/new-chapt...          0.9042  positive

# %%
# Create newsDF for Wayfair
WayFairNews = news_pull('Wayfair News')
# Out:
# Please wait...searching
#  There are 30 pages, with 1502 total articles.
#   datePublished                                        description  \
# 0    07/03/2019         Deep discounts are booming like fireworks!
# 1    06/27/2019  The protest triggered a broader backlash again...
# 2    06/27/2019  Employees at online home furnishings retailer ...
# 3    06/26/2019  Wayfair workers walk out to protest U.S. migra...
# 4    06/26/2019  Catch up on the most important news from today...
#
#                                             keywords     provider  \
# 0  best fourth of july,urban outfitters,wayfair,n...      eonline
# 1   wayfair workers walk out,lakeland,protest,ledger    theledger
# 2             detention center,wayfair,protest,texas         wthr
# 3             wayfair workers walk out,one news page  onenewspage
# 4    facebook data value,wayfair walkout,boston,news        wired
#
#                                                title  \
# 0  Best Fourth of July Sales 2019: Wayfair, Urban...
# 1  Wayfair workers walk out to protest $200,000 s...
# 2  Wayfair workers protest contract with detentio...
# 3   Wayfair workers walk out to protest U.S. migrant
# 4  Wayfair Walkout, Facebook Data Value, and More...
#
#                                                  url sentiment_score sentiment
# 0  https://www.eonline.com/uk/news/1053917/best-f...          0.4199  positive
# 1  https://www.theledger.com/news/20190626/wayfai...         -0.5106  negative
# 2  https://www.wthr.com/article/wayfair-workers-p...         -0.5994  negative
# 3  https://www.onenewspage.com/video/20190627/118...         -0.6705  negative
# 4  https://www.wired.com/story/wayfair-walkout-fa...          0.2716  positive

# %%
# Create newsDF for Wells Fargo
WellsFargoNews = news_pull('Wells Fargo News')
# Out:
# Please wait...searching
#  There are 45 pages, with 2243 total articles.
#   datePublished                                        description  \
# 0    03/29/2019  Wells Fargo news today about company President...
# 1    07/05/2019  Wells Fargo & Co's Irish subsidiary was fined ...
# 2    07/01/2019  Research Analysts updated eps estimates for Mo...
# 3    06/27/2019  The Western Albemarle Athletics Department won...
# 4    06/24/2019  Be the first to get all the important details ...
#
#                                             keywords             provider  \
# 0           wells fargo news,ceo tim sloan,president        investorplace
# 1  reporting breaches,one news page,wells fargo,b...          onenewspage
# 2        updated eps estimates,wells fargo,nyse agco  americanbankingnews
# 3  western albemarle,wells fargo cup,department,s...                nbc29
# 4            wells fargo center,whp 580,news,2019,pm                whptv
#
#                                                title  \
# 0  Wells Fargo News: WFC Stock Lower on CEO Depar...
# 1  Wells Fargo fined in Ireland over reporting br...
# 2  Research Analysts Updated EPS Estimates for Ju...
# 3  WVIR NBC29 Charlottesville News, Sports, and W...
# 4                Ariana Grande at Wells Fargo Center
#
#                                                  url sentiment_score sentiment
# 0  https://investorplace.com/2019/03/wells-fargo-...            0.25  positive
# 1  https://www.onenewspage.com/n/Business/1zkiug6...          0.4215  positive
# 2  https://www.americanbankingnews.com/2019/07/01...          0.4588  positive
# 3  http://www.nbc29.com/story/40719176/western-al...          0.6908  positive
# 4  http://whptv.com/calendar/event/5c128898b50507...          0.2023  positive

# %%
# Create newsDF for Tesla
TeslaNews = news_pull('Tesla News')
# Out:
# Please wait...searching
#  There are 46 pages, with 2304 total articles.
#   datePublished                                        description  \
# 0    06/29/2019  All eyes are on the Model 3 as the new vehicle...
# 1    06/25/2019  This Electrek app provides you with articles r...
# 2    06/12/2019  TESLA CEO is one step closer to becoming a rea...
# 3    05/17/2019  In the latest Tesla news, TSLA stock is sinkin...
# 4    02/28/2019  The billionaire has a surprise up his sleeve f...
#
#                                             keywords       provider  \
# 0                  can model 3 deliveries,tesla news        ibtimes
# 1                 technology,electrek,services,tesla          zdnet
# 2                       tesla news,science,james,car        express
# 3                              tesla model,autopilot  investorplace
# 4  reveal big tesla news,metro news,elon musk,twi...          metro
#
#                                                title  \
# 0    Tesla News: Can Model 3 Deliveries Keep Rising?
# 1                   Technology & Tesla News Download
# 2  Tesla news: Elon Musk's SUBMARINE car is strai...
# 3  Tesla News: Why TSLA Stock Is Tumbling Today T...
# 4  Elon Musk changes Twitter name as he prepares ...
#
#                                                  url sentiment_score sentiment
# 0  http://ibtimes.com/tesla-news-can-model-3-deli...               0  negative
# 1  https://downloads.zdnet.com/product/2164-78131...          0.2732  positive
# 2  https://www.express.co.uk/news/science/1139729...           0.296  positive
# 3  https://investorplace.com/2019/05/tesla-news-t...         -0.4019  negative
# 4  https://metro.co.uk/2019/02/28/elon-musk-chang...          0.2732  positive

# %%
# Create newsDF for Political News
PoliNews = news_pull('Political News')
# Out:
# Please wait...searching
#  There are 37 pages, with 1868 total articles.
#   datePublished                                        description  \
# 0    07/05/2019        Music, Film, TV and Political News Coverage
# 1    07/04/2019        Music, Film, TV and Political News Coverage
# 2    07/02/2019  Arguing an omnibus elections bill signed by Go...
# 3    07/01/2019  Gen Z's go-to source for political news is Ins...
# 4    06/28/2019  The Supreme Court will decide whether Presiden...
#
#                                         keywords           provider  \
# 0          rolling stone,political,music,film,tv       rollingstone
# 1          rolling stone,political,music,film,tv         hypervocal
# 2        florida political news,sunshine,lawsuit  sunshinestatenews
# 3  business insider india,political news,gen,ist    businessinsider
# 4          president donald trump,political news               wthr
#
#                                                title  \
# 0  Amazon Prime Day 2019: How to Get the Best Dea...
# 1  Why QAnon Is Obsessed With John F. Kennedy, Jr...
# 2        State Wants Ballot Signature Lawsuit Tossed
# 3  and it's already having an impact on the 2020 ...
# 4   Supreme Court to decide on Trump bid to end DACA
#
#                                                  url sentiment_score sentiment
# 0  https://www.rollingstone.com/culture/culture-n...               0  negative
# 1                http://hypervocal.com/items/2780760               0  negative
# 2  http://sunshinestatenews.com/story/state-wants...         -0.6369  negative
# 3  http://businessinsider.in/instagram-is-gen-zs-...               0  negative
# 4  https://www.wthr.com/article/supreme-court-dec...          0.5574  positive

# %%
# Create newsDF for Financial News
FinNews = news_pull('Financial News')
# Out:
# Please wait...searching
#  There are 29 pages, with 1446 total articles.
#   datePublished                                        description  \
# 0    07/05/2019  The "Futures Now" team discusses the gold mark...
# 1    07/03/2019  Lagarde has never seemed interested by the fie...
# 2    06/29/2019  MarketWatch provides the latest stock market, ...
# 3    06/26/2019  Business Standard, India's leading business si...
# 4    06/20/2019  THE BUSINESS TIMES - Find latest business & fi...
#
#                                             keywords           provider  \
# 0               financial news,stock quotes,business               cnbc
# 1  lagarde appointment risks,s s making the ecb,f...           fnlondon
# 2  stock market news,financial news,marketwatch,send        marketwatch
# 3          financial news,business news,stock market  business-standard
# 4         business times,financial news,videos,house      businesstimes
#
#                                                title  \
# 0                   Futures Now: Gold feels the heat
# 1  Christine Lagarde appointment risks making the...
# 2                     MarketWatch: Stock Market News
# 3  India News, Latest News Headlines, BSE live, N...
# 4           Get the Latest Business & Financial News
#
#                                                  url sentiment_score sentiment
# 0  https://www.cnbc.com/video/2019/07/05/futures-...               0  negative
# 1  https://www.fnlondon.com/articles/christine-la...         -0.8425  negative
# 2  https://www.marketwatch.com?mod=side_nav/inves...               0  negative
# 3  http://business-standard.com/companies-results...               0  negative
# 4            http://businesstimes.com.sg/atom/174420          0.2023  positive

# %%
import pandas as pd

# %%
# import stock data
nasdaq_data = "nasdaq.csv"
nasdaq_df = pd.read_csv(nasdaq_data)


sp500_data = "sp500.csv"
sp500_df = pd.read_csv(sp500_data)
sp500_df.head()

# Load stock data into notebook as dataframe
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0  6/29/2018  2727.129883  2743.260010  2718.030029  2718.370117  2718.370117
# 1   7/2/2018  2704.949951  2727.260010  2698.949951  2726.709961  2726.709961
# 2   7/3/2018  2733.270020  2736.580078  2711.159912  2713.219971  2713.219971
# 3   7/5/2018  2724.189941  2737.830078  2716.020020  2736.610107  2736.610107
# 4   7/6/2018  2737.679932  2764.409912  2733.520020  2759.820068  2759.820068
#
#        Volume
# 0  3565620000
# 1  3073650000
# 2  1911470000
# 3  2953420000
# 4  2554780000

# %%
nasdaq_df.insert(0, 'Index', 'Nasdaq')
nasdaq_df.head()

sp500_df.insert(0, 'Index', 'S&P 500')
sp500_df.head()
# Out:
#      Index       Date         Open         High          Low        Close  \
# 0  S&P 500  6/29/2018  2727.129883  2743.260010  2718.030029  2718.370117
# 1  S&P 500   7/2/2018  2704.949951  2727.260010  2698.949951  2726.709961
# 2  S&P 500   7/3/2018  2733.270020  2736.580078  2711.159912  2713.219971
# 3  S&P 500   7/5/2018  2724.189941  2737.830078  2716.020020  2736.610107
# 4  S&P 500   7/6/2018  2737.679932  2764.409912  2733.520020  2759.820068
#
#      Adj Close      Volume
# 0  2718.370117  3565620000
# 1  2726.709961  3073650000
# 2  2713.219971  1911470000
# 3  2736.610107  2953420000
# 4  2759.820068  2554780000

# %%
# Merge 2 DataFrames
stock_df = pd.concat([sp500_df, nasdaq_df], ignore_index=True)

#sort by date
stock_df = stock_df.sort_values(by=['Date'])
stock_df.head()
# Out:
#        Index       Date         Open         High          Low        Close  \
# 133  S&P 500  1/10/2019  2573.510010  2597.820068  2562.020020  2596.639893
# 385   Nasdaq  1/10/2019  6908.649902  6991.370117  6877.080078  6986.069824
# 134  S&P 500  1/11/2019  2588.110107  2596.270020  2577.399902  2596.260010
# 386   Nasdaq  1/11/2019  6947.459961  6975.649902  6933.600098  6971.479980
# 387   Nasdaq  1/14/2019  6908.029785  6936.220215  6887.479980  6905.919922
#
#        Adj Close      Volume
# 133  2596.639893  3704500000
# 385  6986.069824  2179080000
# 134  2596.260010  3434490000
# 386  6971.479980  2066500000
# 387  6905.919922  1942210000

# %% [markdown]
# ### About the Scoring (taken from vaderSentiment docs)
# The compound score is computed by summing the valence scores of each word in the lexicon, adjusted according to the rules, and then normalized to be between -1 (most extreme negative) and +1 (most extreme positive). This is the most useful metric if you want a single unidimensional measure of sentiment for a given sentence. Calling it a 'normalized, weighted composite score' is accurate.
#
# It is also useful for researchers who would like to set standardized thresholds for classifying sentences as either positive, neutral, or negative. Typical threshold values (used in the literature cited on this page) are:
#
#     positive sentiment: compound score >= 0.05
#     neutral sentiment: (compound score > -0.05) and (compound score < 0.05)
#     negative sentiment: compound score <= -0.05
# The pos, neu, and neg scores are ratios for proportions of text that fall in each category (so these should all add up to be 1... or close to it with float operation). These are the most useful metrics if you want multidimensional measures of sentiment for a given sentence.

# %%
stock_df['Delta'] = (stock_df.Close - stock_df.Open)*100/stock_df.Open

# %%
stock_df.head()
# Out:
#        Index       Date         Open         High          Low        Close  \
# 133  S&P 500  1/10/2019  2573.510010  2597.820068  2562.020020  2596.639893
# 385   Nasdaq  1/10/2019  6908.649902  6991.370117  6877.080078  6986.069824
# 134  S&P 500  1/11/2019  2588.110107  2596.270020  2577.399902  2596.260010
# 386   Nasdaq  1/11/2019  6947.459961  6975.649902  6933.600098  6971.479980
# 387   Nasdaq  1/14/2019  6908.029785  6936.220215  6887.479980  6905.919922
#
#        Adj Close      Volume     Delta
# 133  2596.639893  3704500000  0.898768
# 385  6986.069824  2179080000  1.120623
# 134  2596.260010  3434490000  0.314898
# 386  6971.479980  2066500000  0.345738
# 387  6905.919922  1942210000 -0.030542

# %%
genNews.head()
# Out:
#   datePublished                                        description  \
# 0    06/30/2019  Quite a few new laws will be implemented in Ge...
# 1    06/28/2019  Watch New movies reviews: Yesterday, Euphoria ...
# 2    06/28/2019  Find and research the best new cars, get best ...
# 3    06/27/2019  International Business News: "Additional tarif...
# 4    06/26/2019  WALLENPAUPACK- Rain clouds past, sunshine retu...
#
#                                             keywords     provider  \
# 0   s will take effect july 1,new georgia laws,these  forsythnews
# 1                       new movie,yesterday,s videos   globalnews
# 2                  car reviews,roadshow,new car,cnet         cnet
# 3    on new tariffs,s on china,trump s,s news,donald   indiatimes
# 4  new chapter opens,s for wahs,s of 2019,s class...       neagle
#
#                                                title  \
# 0     These new Georgia laws will take effect July 1
# 1  New movies reviews: Yesterday, Euphoria and An...
# 2                  New cars, car reviews and pricing
# 3  Donald Trump says will decide on new tariffs o...
# 4           New chapter opens for WAHS Class of 2019
#
#                                                  url sentiment_score sentiment
# 0  https://www.forsythnews.com/local/state-govern...          0.4278  positive
# 1  https://globalnews.ca/video/5442628/new-movies...          0.6486  positive
# 2                      http://cnet.com/roadshow/auto          0.8555  positive
# 3  http://timesofindia.indiatimes.com/world/europ...          0.3094  positive
# 4  https://www.neagle.com/news/20190626/new-chapt...          0.9042  positive

# %%
# change data type of sentiment score to numeric
genNews.sentiment_score = pd.to_numeric(genNews.sentiment_score)

# change name of date column to match stock DF
genNews = genNews.rename(columns = {'datePublished':'Date'})

# %%
genNewsSummary = genNews.groupby('Date')['sentiment_score'].mean()

# %%
genNewsSummary.head()
# Out:
# Date
# 01/01/2013    0.76270
# 01/01/2016    0.61395
# 01/01/2019    0.75680
# 01/02/2019    0.88180
# 01/03/2003    0.31820
# Name: sentiment_score, dtype: float64

# %%
# format date column of stock_df
stock_df.Date = pd.to_datetime(stock_df.Date)
stock_df.Date = stock_df.Date.dt.strftime('%m/%d/%Y')

# %%
stock_df.head()
# Out:
#        Index        Date         Open         High          Low        Close  \
# 133  S&P 500  01/10/2019  2573.510010  2597.820068  2562.020020  2596.639893
# 385   Nasdaq  01/10/2019  6908.649902  6991.370117  6877.080078  6986.069824
# 134  S&P 500  01/11/2019  2588.110107  2596.270020  2577.399902  2596.260010
# 386   Nasdaq  01/11/2019  6947.459961  6975.649902  6933.600098  6971.479980
# 387   Nasdaq  01/14/2019  6908.029785  6936.220215  6887.479980  6905.919922
#
#        Adj Close      Volume     Delta
# 133  2596.639893  3704500000  0.898768
# 385  6986.069824  2179080000  1.120623
# 134  2596.260010  3434490000  0.314898
# 386  6971.479980  2066500000  0.345738
# 387  6905.919922  1942210000 -0.030542

# %%
# Merge 2 dataframes on Date
genNewsCombined = pd.merge(stock_df,genNewsSummary, on = 'Date', how = 'inner')

# %%
genNewsCombined.head()
# Out:
#      Index        Date         Open         High          Low        Close  \
# 0  S&P 500  01/10/2019  2573.510010  2597.820068  2562.020020  2596.639893
# 1   Nasdaq  01/10/2019  6908.649902  6991.370117  6877.080078  6986.069824
# 2  S&P 500  01/11/2019  2588.110107  2596.270020  2577.399902  2596.260010
# 3   Nasdaq  01/11/2019  6947.459961  6975.649902  6933.600098  6971.479980
# 4   Nasdaq  01/14/2019  6908.029785  6936.220215  6887.479980  6905.919922
#
#      Adj Close      Volume     Delta  sentiment_score
# 0  2596.639893  3704500000  0.898768          0.27320
# 1  6986.069824  2179080000  1.120623          0.27320
# 2  2596.260010  3434490000  0.314898          0.08180
# 3  6971.479980  2066500000  0.345738          0.08180
# 4  6905.919922  1942210000 -0.030542          0.27625

# %%
# find correlation coefficient between Delta and sentiment_score column
genNewsCorrelation = sp.pearsonr(genNewsCombined.Delta,genNewsCombined.sentiment_score)
print(f'The correlation between the delta and sentiment scores for general news \nis {genNewsCorrelation[0]}, with a P value of {genNewsCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for general news
# is -0.030709099644561776, with a P value of 0.6140829369034249

# %%
# Use Matplotlib and stats to generate graphs and look for relationships
#S&P Scatterplot
genNewsCombinedSP = genNewsCombined.loc[(genNewsCombined["Index"] == "S&P 500")]
sentiment_score_SP = genNewsCombinedSP['sentiment_score']
delta_SP = genNewsCombinedSP['Delta']


plt.title("General News - S&P 500: Sentiment Score vs Stock Change %")
plt.xlabel("Stock Price")
plt.ylabel("Sentiment Score")

plt.scatter(delta_SP, sentiment_score_SP , marker="o", facecolors="red", edgecolors="black",
            alpha=0.75)
plt.savefig("General News - S&P 500: Sentiment Score vs Stock Change % Scat.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for General News S&P 500
genNewsSPCorrelation = sp.pearsonr(genNewsCombinedSP.Delta,genNewsCombinedSP.sentiment_score)
print(f'The correlation between the delta and sentiment scores for General News S&P 500 \nis {genNewsSPCorrelation[0]}, with a P value of {genNewsSPCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for General News S&P 500
# is -0.020960730843469774, with a P value of 0.8086156111855279

# %%
#Nasdaq Scatterplot
genNewsCombinedNSQ = genNewsCombined.loc[(genNewsCombined["Index"] == "Nasdaq")]
sentiment_score_NSQ = genNewsCombinedNSQ['sentiment_score']
delta_NSQ = genNewsCombinedNSQ['Delta']


plt.title("General News - Nasdaq: Sentiment Score vs Stock Change %")
plt.xlabel("Stock Price")
plt.ylabel("Sentiment Score")

plt.scatter(delta_NSQ, sentiment_score_NSQ , marker="o", facecolors="red", edgecolors="black",
            alpha=0.75)

plt.savefig("General News - Nasdaq: Sentiment Score vs Stock Change % Scat.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for General News Nasdaq
genNewsNSQCorrelation = sp.pearsonr(genNewsCombinedNSQ.Delta,genNewsCombinedNSQ.sentiment_score)
print(f'The correlation between the delta and sentiment scores for General News Nasdaq \nis {genNewsNSQCorrelation[0]}, with a P value of {genNewsNSQCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for General News Nasdaq
# is -0.03871689247380876, with a P value of 0.6545047428559096

# %%
#Nasdaq dataframe change to groupby month
genNewsCombinedNSQ['Date'] = pd.to_datetime(genNewsCombinedNSQ['Date'])
genNewsCombinedNSQ['month'] = genNewsCombinedNSQ['Date'].dt.to_period('M')
genNewsCombinedNSQ
# Out:
# C:\Users\19086\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users
genNewsCombinedNSQ_df['sentiment_score'] = genNewsCombinedNSQ.groupby('month')['sentiment_score'].mean()
genNewsCombinedNSQ_df
# Out:
#             Delta  sentiment_score
# month
# 2018-06 -0.448429        -0.401900
# 2018-07 -0.284078         0.389800
# 2018-08  0.152930        -0.213757
# 2018-09  0.150521         0.335271
# 2018-10 -0.625555         0.286898
# 2018-11  0.029154         0.327587
# 2018-12 -0.371929         0.591129
# 2019-01  0.456953         0.308657
# 2019-02  0.455372         0.230157
# 2019-03  0.300378         0.153606
# 2019-04  0.131018         0.096204
# 2019-05  0.018948         0.026423
# 2019-06 -0.016935        -0.007842

# %%
genNewsCombinedNSQ_df.reset_index(inplace=True)

# %%
genNewsCombinedNSQ_df.month = genNewsCombinedNSQ_df.month.dt.strftime('%m/%Y')

# %%
delta_month_nsq = genNewsCombinedNSQ_df['Delta']
score_month_nsq = genNewsCombinedNSQ_df['sentiment_score']
date = genNewsCombinedNSQ_df['month']

plt.plot(date,delta_month_nsq)
plt.plot(date,score_month_nsq)
plt.xticks(rotation=45)
plt.title("General News - Nasdaq: Stock % Change vs Sentiment Score")
plt.xlabel("Date")
plt.legend(['Stock % Change','Sentiment Score'])
plt.savefig("General News - Nasdaq: Stock % Change vs Sentiment Score Line.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for the summarized General News Nasdaq
genNewsNSQSumCorrelation = sp.pearsonr(delta_month_nsq,score_month_nsq)
print(f'The correlation between the delta and sentiment scores for the General News Nasdaq summary \nis {genNewsNSQSumCorrelation[0]}, with a P value of {genNewsNSQSumCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for the General News Nasdaq summary
# is 0.010307127215561844, with a P value of 0.9733407473643522

# %%
#S&P Grouping by Month and averging out Delta and Sentiment Scores
genNewsCombinedSP['Date'] = pd.to_datetime(genNewsCombinedSP['Date'])
genNewsCombinedSP['month'] = genNewsCombinedSP['Date'].dt.to_period('M')
genNewsCombinedSP
# Out:
# C:\Users\19086\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\19086\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        Index       Date         Open         High          Low        Close  \
# 0    S&P 500 2019-01-10  2573.510010  2597.820068  2562.020020  2596.639893
# 2    S&P 500 2019-01-11  2588.110107  2596.270020  2577.399902  2596.260010
# 5    S&P 500 2019-01-14  2580.310059  2589.320068  2570.409912  2582.610107
# 7    S&P 500 2019-01-15  2585.100098  2613.080078  2585.100098  2610.300049
# 9    S&P 500 2019-01-16  2614.750000  2625.760010  2612.679932  2616.100098
# 10   S&P 500 2019-01-02  2476.959961  2519.489990  2467.469971  2510.030029
# 13   S&P 500 2019-01-22  2657.879883  2657.879883  2617.270020  2632.899902
# 14   S&P 500 2019-01-29  2644.889893  2650.929932  2631.050049  2640.000000
# 16   S&P 500 2019-01-07  2535.610107  2566.159912  2524.560059  2549.689941
# 18   S&P 500 2018-10-01  2926.290039  2937.060059  2917.909912  2924.590088
# 20   S&P 500 2018-10-10  2873.899902  2874.020020  2784.860107  2785.679932
# 23   S&P 500 2018-10-15  2763.830078  2775.989990  2749.030029  2750.790039
# 25   S&P 500 2018-10-16  2767.050049  2813.459961  2766.909912  2809.919922
# 26   S&P 500 2018-10-17  2811.669922  2816.939941  2781.810059  2809.209961
# 29   S&P 500 2018-10-22  2773.939941  2778.939941  2749.219971  2755.879883
# 30   S&P 500 2018-10-24  2737.870117  2742.590088  2651.889893  2656.100098
# 230  2801.310059  2614000000  0.156605         0.700300  2018-07
# 232  2798.429932  2812230000  0.038244         0.932500  2018-07
# 235  2806.979980  2907430000  0.279013         0.128000  2018-07
# 236  2837.439941  3653330000  0.068769         0.000000  2018-07
# 238  2818.820068  3415710000 -0.827837         0.000000  2018-07
# 240  2713.219971  1911470000 -0.733555         0.686500  2018-07
# 243  2736.610107  2953420000  0.455921         0.000000  2018-07
# 244  2839.959961  2976970000  0.427178         0.318200  2018-08
# 246  2818.370117  3645070000 -0.338755        -0.855500  2018-08
# 248  2840.689941  3219880000  0.326689         0.847800  2018-08
# 250  2861.820068  2689560000  0.029014        -0.690800  2018-08
# 253  2874.689941  2596190000  0.431109         0.202300  2018-08
# 254  2901.520020  2880260000  0.108678        -0.440400  2018-08
# 256  2853.580078  3047050000 -0.126343        -0.877900  2018-08
# 259  2888.919922  3264930000  0.021808         0.977900  2018-09
# 261  2904.179932  3254930000  0.253028        -0.125000  2018-09
# 262  2904.310059  3074610000  0.469432        -0.648600  2018-09
# 264  2907.949951  3280020000  0.046441         0.000000  2018-09
# 267  2930.750000  3337730000  0.377433         0.697600  2018-09
# 269  2929.669922  5607610000 -0.241426         0.859100  2018-09
# 270  2919.370117  3372210000 -0.084192         0.585900  2018-09
#
# [136 rows x 11 columns]

# %%
genNewsCombinedSPMonth = genNewsCombinedSP.groupby('month')["Delta"].mean()
genNewsCombinedSP_df = pd.DataFrame(genNewsCombinedSPMonth)
genNewsCombinedSP_df['sentiment_score'] = genNewsCombinedSP.groupby('month')['sentiment_score'].mean()
genNewsCombinedSP_df
# Out:
#             Delta  sentiment_score
# month
# 2018-06 -0.321208        -0.401900
# 2018-07 -0.096436         0.389800
# 2018-08  0.122510        -0.213757
# 2018-09  0.120361         0.335271
# 2018-10 -0.384841         0.286898
# 2018-11  0.030064         0.327587
# 2018-12 -0.276758         0.591129
# 2019-01  0.343880         0.308657
# 2019-02  0.281556         0.230157
# 2019-03  0.262679         0.153606
# 2019-04  0.103292         0.096204
# 2019-05 -0.045686         0.026423
# 2019-06  0.090758        -0.007842

# %%
genNewsCombinedSP_df.reset_index(inplace=True)
genNewsCombinedSP_df
# Out:
#       month     Delta  sentiment_score
# 0   2018-06 -0.321208        -0.401900
# 1   2018-07 -0.096436         0.389800
# 2   2018-08  0.122510        -0.213757
# 3   2018-09  0.120361         0.335271
# 4   2018-10 -0.384841         0.286898
# 5   2018-11  0.030064         0.327587
# 6   2018-12 -0.276758         0.591129
# 7   2019-01  0.343880         0.308657
# 8   2019-02  0.281556         0.230157
# 9   2019-03  0.262679         0.153606
# 10  2019-04  0.103292         0.096204
# 11  2019-05 -0.045686         0.026423
# 12  2019-06  0.090758        -0.007842

# %%
genNewsCombinedSP_df.month = genNewsCombinedSP_df.month.dt.strftime('%m/%Y')

# %%
delta_month_sp = genNewsCombinedSP_df['Delta']
score_month_sp = genNewsCombinedSP_df['sentiment_score']
date = genNewsCombinedSP_df['month']

plt.plot(date,delta_month_sp)
plt.plot(date,score_month_sp)
plt.xticks(rotation=45)
plt.title("General News - S&P 500: Stock % Change vs S. Score")
plt.xlabel("Date")
plt.legend(['Stock % Change','Sentiment Score'])
plt.savefig("General News - S&P 500: Stock % Change vs S. Score Line.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for General News S&P 500 Summary
genNewsSPSumCorrelation = sp.pearsonr(delta_month_sp,score_month_sp)
print(f'The correlation between the delta and sentiment score trends for the General News S&P 500 Summary \nis {genNewsSPSumCorrelation[0]}, with a P value of {genNewsSPSumCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment score trends for the General News S&P 500 Summary
# is 0.03131857902173626, with a P value of 0.919101064452605

# %%
tesla_data = "TSLA.csv"
tesla_df = pd.read_csv("TSLA.csv")
tesla_df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-06-29  353.329987  353.859985  342.410004  342.950012  342.950012
# 1  2018-07-02  360.070007  364.779999  329.850006  335.070007  335.070007
# 2  2018-07-03  331.750000  332.489990  309.690002  310.859985  310.859985
# 3  2018-07-05  313.760010  314.390015  296.220001  309.160004  309.160004
# 4  2018-07-06  304.950012  312.070007  302.000000  308.899994  308.899994
#
#      Volume
# 0   6492400
# 1  18759800
# 2  12282600
# 3  17476400
# 4   8865500

# %%
tesla_df['Delta'] = (tesla_df.Close - tesla_df.Open )*100/tesla_df.Open

# %%
tesla_df = tesla_df.sort_values(by=['Date'])
tesla_df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-06-29  353.329987  353.859985  342.410004  342.950012  342.950012
# 1  2018-07-02  360.070007  364.779999  329.850006  335.070007  335.070007
# 2  2018-07-03  331.750000  332.489990  309.690002  310.859985  310.859985
# 3  2018-07-05  313.760010  314.390015  296.220001  309.160004  309.160004
# 4  2018-07-06  304.950012  312.070007  302.000000  308.899994  308.899994
#
#      Volume     Delta
# 0   6492400 -2.937757
# 1  18759800 -6.943094
# 2  12282600 -6.296915
# 3  17476400 -1.466091
# 4   8865500  1.295288

# %%
tesla_df.Date = pd.to_datetime(tesla_df.Date)

# %%
tesla_df.Date = tesla_df.Date.dt.strftime('%m/%d/%Y')

# %%
TeslaNews.head()
# Out:
#   datePublished                                        description  \
# 0    06/29/2019  All eyes are on the Model 3 as the new vehicle...
# 1    06/25/2019  This Electrek app provides you with articles r...
# 2    06/12/2019  TESLA CEO is one step closer to becoming a rea...
# 3    05/17/2019  In the latest Tesla news, TSLA stock is sinkin...
# 4    02/28/2019  The billionaire has a surprise up his sleeve f...
#
#                                             keywords       provider  \
# 0                  can model 3 deliveries,tesla news        ibtimes
# 1                 technology,electrek,services,tesla          zdnet
# 2                       tesla news,science,james,car        express
# 3                              tesla model,autopilot  investorplace
# 4  reveal big tesla news,metro news,elon musk,twi...          metro
#
#                                                title  \
# 0    Tesla News: Can Model 3 Deliveries Keep Rising?
# 1                   Technology & Tesla News Download
# 2  Tesla news: Elon Musk's SUBMARINE car is strai...
# 3  Tesla News: Why TSLA Stock Is Tumbling Today T...
# 4  Elon Musk changes Twitter name as he prepares ...
#
#                                                  url sentiment_score sentiment
# 0  http://ibtimes.com/tesla-news-can-model-3-deli...               0  negative
# 1  https://downloads.zdnet.com/product/2164-78131...          0.2732  positive
# 2  https://www.express.co.uk/news/science/1139729...           0.296  positive
# 3  https://investorplace.com/2019/05/tesla-news-t...         -0.4019  negative
# 4  https://metro.co.uk/2019/02/28/elon-musk-chang...          0.2732  positive

# %%
# change data type of sentiment score to numeric
TeslaNews.sentiment_score = pd.to_numeric(TeslaNews.sentiment_score)

# change name of date column to match stock DF
TeslaNews = TeslaNews.rename(columns = {'datePublished':'Date'})

# %%
TeslaNewsSummary = TeslaNews.groupby('Date')['sentiment_score'].mean()

# %%
TeslaNewsSummary.head()
# Out:
# Date
# 01/11/2011    0.4588
# 01/12/2019    0.4019
# 01/30/2019    0.5106
# 02/07/2019    0.2023
# 02/28/2019    0.2732
# Name: sentiment_score, dtype: float64

# %%
# Merge 2 dataframes on Date
TeslaNewsCombined = pd.merge(tesla_df,TeslaNewsSummary, on = 'Date', how = 'inner')

# %%
TeslaNewsCombined.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  06/29/2018  353.329987  353.859985  342.410004  342.950012  342.950012
# 1  07/10/2018  324.559998  327.679993  319.200012  322.470001  322.470001
# 2  07/13/2018  315.579987  319.579987  309.250000  318.869995  318.869995
# 3  07/16/2018  311.709991  315.160004  306.250000  310.100006  310.100006
# 4  07/19/2018  316.329987  323.540009  314.010010  320.230011  320.230011
#
#     Volume     Delta  sentiment_score
# 0  6492400 -2.937757           0.0258
# 1  9471500 -0.643948          -0.6597
# 2  5869800  1.042527          -0.4404
# 3  7818700 -0.516501          -0.1779
# 4  5915300  1.232897           0.0000

# %%
sentiment_score_TSLA = TeslaNewsCombined['sentiment_score']
delta_TSLA = TeslaNewsCombined['Delta']

plt.title("Tesla: Sentiment Score vs Stock Change %")
plt.xlabel("Stock % Change")
plt.ylabel("Sentiment Score")

plt.scatter(delta_TSLA, sentiment_score_TSLA , marker="o", facecolors="red", edgecolors="black",
            alpha=0.75)
plt.savefig("Tesla: Sentiment Score vs Stock Change % Scat.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for Tesla
TeslaCorrelation = sp.pearsonr(delta_TSLA,sentiment_score_TSLA)
print(f'The correlation between the delta and sentiment scores for Tesla News \nis {TeslaCorrelation[0]}, with a P value of {TeslaCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for Tesla News
# is 0.17873183173657342, with a P value of 0.17560049751575973

# %%
TeslaNewsCombined['Date'] = pd.to_datetime(TeslaNewsCombined['Date'])
TeslaNewsCombined['month'] = TeslaNewsCombined['Date'].dt.to_period('M')
TeslaNewsCombined.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2018-06-29  353.329987  353.859985  342.410004  342.950012  342.950012
# 1 2018-07-10  324.559998  327.679993  319.200012  322.470001  322.470001
# 2 2018-07-13  315.579987  319.579987  309.250000  318.869995  318.869995
# 3 2018-07-16  311.709991  315.160004  306.250000  310.100006  310.100006
# 4 2018-07-19  316.329987  323.540009  314.010010  320.230011  320.230011
#
#     Volume     Delta  sentiment_score    month
# 0  6492400 -2.937757           0.0258  2018-06
# 1  9471500 -0.643948          -0.6597  2018-07
# 2  5869800  1.042527          -0.4404  2018-07
# 3  7818700 -0.516501          -0.1779  2018-07
# 4  5915300  1.232897           0.0000  2018-07

# %%
TeslaNewsCombinedMonth = TeslaNewsCombined.groupby('month')["Delta"].mean()
TeslaNewsCombined_df = pd.DataFrame(TeslaNewsCombinedMonth)
TeslaNewsCombined_df['sentiment_score'] = TeslaNewsCombined.groupby('month')['sentiment_score'].mean()
TeslaNewsCombined_df
# Out:
#             Delta  sentiment_score
# month
# 2018-06 -2.937757         0.025800
# 2018-07 -0.236240        -0.255600
# 2018-08  0.399368         0.843900
# 2018-10  2.957880        -0.180600
# 2018-11  0.264315        -0.153100
# 2018-12  8.696665         0.000000
# 2019-01  2.769172         0.510600
# 2019-02 -0.773524         0.237750
# 2019-03 -2.849994        -0.590400
# 2019-04  0.108629        -0.164225
# 2019-05 -0.603724        -0.000113
# 2019-06  0.254580         0.072384

# %%
TeslaNewsCombined_df.reset_index(inplace=True)
TeslaNewsCombined_df
# Out:
#       month     Delta  sentiment_score
# 0   2018-06 -2.937757         0.025800
# 1   2018-07 -0.236240        -0.255600
# 2   2018-08  0.399368         0.843900
# 3   2018-10  2.957880        -0.180600
# 4   2018-11  0.264315        -0.153100
# 5   2018-12  8.696665         0.000000
# 6   2019-01  2.769172         0.510600
# 7   2019-02 -0.773524         0.237750
# 8   2019-03 -2.849994        -0.590400
# 9   2019-04  0.108629        -0.164225
# 10  2019-05 -0.603724        -0.000113
# 11  2019-06  0.254580         0.072384

# %%
from datetime import datetime

#TeslaNewsCombined_df.month = pd.to_datetime(TeslaNewsCombined_df['month'])

# %%
TeslaNewsCombined_df.month = TeslaNewsCombined_df.month.dt.strftime('%m/%Y')

# %%
delta_month_TSLA = TeslaNewsCombined_df['Delta']
score_month_TSLA = TeslaNewsCombined_df['sentiment_score']
date = TeslaNewsCombined_df['month']

plt.plot(date,delta_month_TSLA)
plt.plot(date,score_month_TSLA)
plt.xticks(rotation=45)
plt.title("Tesla: Sentiment Score vs Stock % Change")
plt.xlabel("Date")
plt.legend(['Stock % Change','Sentiment Score'])
plt.savefig("Tesla: Sentiment Score vs Stock Change % Line.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for the Tesla monthly summary
TeslaSummaryCorrelation = sp.pearsonr(delta_month_TSLA,score_month_TSLA)
print(f'The correlation between the delta and sentiment scores for Tesla monthly News \nis {TeslaSummaryCorrelation[0]}, with a P value of {TeslaSummaryCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for Tesla monthly News
# is 0.192292999216793, with a P value of 0.549346901606173

# %%
#Bring in Wayfair stock data
wayfair_data = "W.csv"
wayfair_df = pd.read_csv("W.csv")
wayfair_df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-06-29  118.889999  119.500000  116.642998  118.760002  118.760002
# 1  2018-07-02  117.470001  117.620003  115.360001  115.910004  115.910004
# 2  2018-07-03  117.589996  118.074997  115.000000  115.940002  115.940002
# 3  2018-07-05  117.269997  117.900002  114.660004  117.820000  117.820000
# 4  2018-07-06  117.419998  122.050003  117.330002  121.739998  121.739998
#
#     Volume
# 0  1117400
# 1  1346200
# 2   607500
# 3   978300
# 4  1344000

# %%
#Add delta column
wayfair_df['Delta'] = (wayfair_df.Open - wayfair_df.Close)*100/wayfair_df.Open

# %%
#Sort by dates
wayfair_df = wayfair_df.sort_values(by=['Date'])
wayfair_df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-06-29  118.889999  119.500000  116.642998  118.760002  118.760002
# 1  2018-07-02  117.470001  117.620003  115.360001  115.910004  115.910004
# 2  2018-07-03  117.589996  118.074997  115.000000  115.940002  115.940002
# 3  2018-07-05  117.269997  117.900002  114.660004  117.820000  117.820000
# 4  2018-07-06  117.419998  122.050003  117.330002  121.739998  121.739998
#
#     Volume     Delta
# 0  1117400  0.109342
# 1  1346200  1.327996
# 2   607500  1.403175
# 3   978300 -0.469006
# 4  1344000 -3.679101

# %%
#Convert column to datetime
wayfair_df.Date = pd.to_datetime(wayfair_df.Date)

# %%
#Reformat date column
wayfair_df.Date = wayfair_df.Date.dt.strftime('%m/%d/%Y')
wayfair_df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  06/29/2018  118.889999  119.500000  116.642998  118.760002  118.760002
# 1  07/02/2018  117.470001  117.620003  115.360001  115.910004  115.910004
# 2  07/03/2018  117.589996  118.074997  115.000000  115.940002  115.940002
# 3  07/05/2018  117.269997  117.900002  114.660004  117.820000  117.820000
# 4  07/06/2018  117.419998  122.050003  117.330002  121.739998  121.739998
#
#     Volume     Delta
# 0  1117400  0.109342
# 1  1346200  1.327996
# 2   607500  1.403175
# 3   978300 -0.469006
# 4  1344000 -3.679101

# %%
# change data type of sentiment score to numeric
WayFairNews.sentiment_score = pd.to_numeric(WayFairNews.sentiment_score)

# change name of date column to match stock DF
WayFairNews = WayFairNews.rename(columns = {'datePublished':'Date'})

# %%
#Create Summary table grouping by Date
WayFairNewsSummary = WayFairNews.groupby('Date')['sentiment_score'].mean()
WayFairNewsSummary.head()
# Out:
# Date
# 01/01/2019    0.310000
# 01/02/2019    0.000000
# 01/04/2019    0.968200
# 01/05/2019    0.891000
# 01/06/2019    0.251529
# Name: sentiment_score, dtype: float64

# %%
#Merge the stock data and the news sentiment data
WayFairNewsCombined = pd.merge(wayfair_df,WayFairNewsSummary, on = 'Date', how = 'inner')
WayFairNewsCombined.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  07/02/2018  117.470001  117.620003  115.360001  115.910004  115.910004
# 1  07/05/2018  117.269997  117.900002  114.660004  117.820000  117.820000
# 2  08/13/2018  123.239998  125.290001  121.120003  122.269997  122.269997
# 3  08/16/2018  120.879997  121.050003  117.362000  118.680000  118.680000
# 4  08/17/2018  119.050003  120.120003  117.275002  119.309998  119.309998
#
#     Volume     Delta  sentiment_score
# 0  1346200  1.327996         0.000000
# 1   978300 -0.469006        -0.728100
# 2  1616500  0.787083         0.421500
# 3   724900  1.819984         0.222933
# 4   859700 -0.218391         0.344033

# %%
#Plot Wayfair scatter plot to see if there is a correlation
sentiment_score_W = WayFairNewsCombined['sentiment_score']
delta_W = WayFairNewsCombined['Delta']

plt.title("Wayfair: Sentiment Score vs Stock Change %")
plt.xlabel("Stock % Change")
plt.ylabel("Sentiment Score")

plt.scatter(delta_W, sentiment_score_W , marker="o", facecolors="red", edgecolors="black",
            alpha=0.75)
plt.savefig("Wayfair: Sentiment Score vs Stock Change %Scat.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for Wayfair News
WayfairCorrelation = sp.pearsonr(delta_W,sentiment_score_W)
print(f'The correlation between the delta and sentiment scores for Wayfair News \nis {WayfairCorrelation[0]}, with a P value of {WayfairCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for Wayfair News
# is -0.04346585395311832, with a P value of 0.5494192047471895

# %%
#Convert and add a new column to show only the month
WayFairNewsCombined['Date'] = pd.to_datetime(WayFairNewsCombined['Date'])
WayFairNewsCombined['month'] = WayFairNewsCombined['Date'].dt.to_period('M')
WayFairNewsCombined.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2018-07-02  117.470001  117.620003  115.360001  115.910004  115.910004
# 1 2018-07-05  117.269997  117.900002  114.660004  117.820000  117.820000
# 2 2018-08-13  123.239998  125.290001  121.120003  122.269997  122.269997
# 3 2018-08-16  120.879997  121.050003  117.362000  118.680000  118.680000
# 4 2018-08-17  119.050003  120.120003  117.275002  119.309998  119.309998
#
#     Volume     Delta  sentiment_score    month
# 0  1346200  1.327996         0.000000  2018-07
# 1   978300 -0.469006        -0.728100  2018-07
# 2  1616500  0.787083         0.421500  2018-08
# 3   724900  1.819984         0.222933  2018-08
# 4   859700 -0.218391         0.344033  2018-08

# %%
#Create new dataframe to group by month
WayFairNewsCombinedMonth = WayFairNewsCombined.groupby('month')["Delta"].mean()
WayFairNewsCombined_df = pd.DataFrame(WayFairNewsCombinedMonth)
WayFairNewsCombined_df['sentiment_score'] = WayFairNewsCombined.groupby('month')['sentiment_score'].mean()
WayFairNewsCombined_df
# Out:
#             Delta  sentiment_score
# month
# 2018-07  0.429495        -0.364050
# 2018-08 -0.550600         0.392302
# 2018-09 -0.900299         0.401599
# 2018-10  1.749845         0.390755
# 2018-11 -0.926878         0.422265
# 2018-12  1.489572         0.307700
# 2019-01 -1.292975         0.295555
# 2019-02 -0.958850         0.254478
# 2019-03  0.605020         0.103447
# 2019-04 -0.111925         0.339747
# 2019-05 -0.518810         0.102015
# 2019-06  0.285485         0.153131

# %%
#Reset the index
WayFairNewsCombined_df.reset_index(inplace=True)
WayFairNewsCombined_df
# Out:
#       month     Delta  sentiment_score
# 0   2018-07  0.429495        -0.364050
# 1   2018-08 -0.550600         0.392302
# 2   2018-09 -0.900299         0.401599
# 3   2018-10  1.749845         0.390755
# 4   2018-11 -0.926878         0.422265
# 5   2018-12  1.489572         0.307700
# 6   2019-01 -1.292975         0.295555
# 7   2019-02 -0.958850         0.254478
# 8   2019-03  0.605020         0.103447
# 9   2019-04 -0.111925         0.339747
# 10  2019-05 -0.518810         0.102015
# 11  2019-06  0.285485         0.153131

# %%
#Import datetime
from datetime import datetime

TeslaNewsCombined_df.month = pd.to_datetime(TeslaNewsCombined_df['month'])

# %%
#Convert date to have month be first
WayFairNewsCombined_df.month = WayFairNewsCombined_df.month.dt.strftime('%m/%Y')

# %%
#Plot line graph over a year's time showing stock change and sentiment score.
delta_month_W = WayFairNewsCombined_df['Delta']
score_month_W = WayFairNewsCombined_df['sentiment_score']
date = WayFairNewsCombined_df['month']

plt.plot(date,delta_month_W)
plt.plot(date,score_month_W)
plt.xticks(rotation=45)
plt.title("Wayfair: Sentiment Score vs Stock % Change")
plt.xlabel("Date")
plt.legend(['Stock % Change','Sentiment Score'])
plt.savefig("Wayfair: Sentiment Score vs Stock % Change Line.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for Wayfair Monthly News
WayfairMonthCorrelation = sp.pearsonr(delta_month_W,score_month_W)
print(f'The correlation between the delta and sentiment scores for Wayfair Monthly News Trends \nis {WayfairMonthCorrelation[0]}, with a P value of {WayfairMonthCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for Wayfair Monthly News Trends
# is -0.18018764419871044, with a P value of 0.5752133184786916

# %%
#Bring in Wells Fargo stock data
wells_data = "WFC.csv"
wells_df = pd.read_csv("WFC.csv")
wells_df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2018-06-29  55.619999  57.119999  55.410000  55.439999  53.587044  43888500
# 1  2018-07-02  55.200001  56.380001  55.070000  56.320000  54.437630  21204900
# 2  2018-07-03  56.430000  56.630001  55.430000  55.560001  53.703026  12830400
# 3  2018-07-05  55.919998  56.080002  55.049999  55.240002  53.393730  16788600
# 4  2018-07-06  55.299999  56.130001  55.029999  55.889999  54.021999  12389100

# %%
#Add delta column
wells_df['Delta'] = (wells_df.Close - wells_df.Open)*100/wells_df.Open

# %%
#Sort by dates
wells_df = wells_df.sort_values(by=['Date'])
wells_df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2018-06-29  55.619999  57.119999  55.410000  55.439999  53.587044
# 1  2018-07-02  55.200001  56.380001  55.070000  56.320000  54.437630
# 2  2018-07-03  56.430000  56.630001  55.430000  55.560001  53.703026
# 3  2018-07-05  55.919998  56.080002  55.049999  55.240002  53.393730
# 4  2018-07-06  55.299999  56.130001  55.029999  55.889999  54.021999
#
#      Volume     Delta
# 0  43888500 -0.323625
# 1  21204900  2.028984
# 2  12830400 -1.541731
# 3  16788600 -1.216016
# 4  12389100  1.066908

# %%
#Convert column to datetime
wells_df.Date = pd.to_datetime(wells_df.Date)

# %%
#Reformat date column
wells_df.Date = wells_df.Date.dt.strftime('%m/%d/%Y')
wells_df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  06/29/2018  55.619999  57.119999  55.410000  55.439999  53.587044
# 1  07/02/2018  55.200001  56.380001  55.070000  56.320000  54.437630
# 2  07/03/2018  56.430000  56.630001  55.430000  55.560001  53.703026
# 3  07/05/2018  55.919998  56.080002  55.049999  55.240002  53.393730
# 4  07/06/2018  55.299999  56.130001  55.029999  55.889999  54.021999
#
#      Volume     Delta
# 0  43888500 -0.323625
# 1  21204900  2.028984
# 2  12830400 -1.541731
# 3  16788600 -1.216016
# 4  12389100  1.066908

# %%
# change data type of sentiment score to numeric
WellsFargoNews.sentiment_score = pd.to_numeric(WellsFargoNews.sentiment_score)

# change name of date column to match stock DF
WellsFargoNews = WellsFargoNews.rename(columns = {'datePublished':'Date'})

# %%
#Create Summary table grouping by Date
WellsFargoNewsSummary = WellsFargoNews.groupby('Date')['sentiment_score'].mean()
WellsFargoNewsSummary.head()
# Out:
# Date
# 01/09/2018    0.250000
# 01/11/2004    0.000000
# 01/13/2019    0.557400
# 01/14/2019    0.502800
# 01/15/2019    0.574767
# Name: sentiment_score, dtype: float64

# %%
#Merge the stock data and the news sentiment data
WellsFargoNewsCombined = pd.merge(wells_df,WellsFargoNewsSummary, on = 'Date', how = 'inner')
WellsFargoNewsCombined.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  08/01/2018  57.959999  58.279999  57.209999  57.650002  55.723179
# 1  08/28/2018  59.189999  59.330002  58.990002  59.070000  57.513538
# 2  10/12/2018  52.099998  53.330002  50.869999  52.110001  50.736931
# 3  10/18/2018  54.169998  54.400002  52.759998  53.099998  51.700844
# 4  10/26/2018  51.320000  51.930000  50.790001  51.250000  49.899590
#
#      Volume     Delta  sentiment_score
# 0  19192700 -0.534846           0.7845
# 1  19330200 -0.202735           0.6249
# 2  32067300  0.019200           0.2500
# 3  22533300 -1.975263          -0.2263
# 4  30053800 -0.136399           0.6124

# %%
#Plot Wayfair scatter plot to see if there is a correlation
sentiment_score_WFC = WellsFargoNewsCombined['sentiment_score']
delta_WFC = WellsFargoNewsCombined['Delta']

plt.title("Wells Fargo: Sentiment Score vs Stock Change %")
plt.xlabel("Stock % Change")
plt.ylabel("Sentiment Score")

plt.scatter(delta_WFC, sentiment_score_WFC, marker="o", facecolors="red", edgecolors="black",
            alpha=0.75)
plt.savefig("Wells Fargo: Sentiment Score vs Stock Change % Scat.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for Wells Fargo News
WellsFargoCorrelation = sp.pearsonr(delta_WFC,sentiment_score_WFC)
print(f'The correlation between the delta and sentiment scores for Wells Fargo News \nis {WellsFargoCorrelation[0]}, with a P value of {WellsFargoCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for Wells Fargo News
# is 0.014297576836619485, with a P value of 0.8737488103381466

# %%
#Convert and add a new column to show only the month
WellsFargoNewsCombined['Date'] = pd.to_datetime(WellsFargoNewsCombined['Date'])
WellsFargoNewsCombined['month'] = WellsFargoNewsCombined['Date'].dt.to_period('M')
WellsFargoNewsCombined.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close    Volume  \
# 0 2018-08-01  57.959999  58.279999  57.209999  57.650002  55.723179  19192700
# 1 2018-08-28  59.189999  59.330002  58.990002  59.070000  57.513538  19330200
# 2 2018-10-12  52.099998  53.330002  50.869999  52.110001  50.736931  32067300
# 3 2018-10-18  54.169998  54.400002  52.759998  53.099998  51.700844  22533300
# 4 2018-10-26  51.320000  51.930000  50.790001  51.250000  49.899590  30053800
#
#       Delta  sentiment_score    month
# 0 -0.534846           0.7845  2018-08
# 1 -0.202735           0.6249  2018-08
# 2  0.019200           0.2500  2018-10
# 3 -1.975263          -0.2263  2018-10
# 4 -0.136399           0.6124  2018-10

# %%
#Create new dataframe to group by month
WellsFargoNewsCombinedMonth = WellsFargoNewsCombined.groupby('month')["Delta"].mean()
WellsFargoNewsCombined_df = pd.DataFrame(WellsFargoNewsCombinedMonth)
WellsFargoNewsCombined_df['sentiment_score'] = WellsFargoNewsCombined.groupby('month')['sentiment_score'].mean()
WellsFargoNewsCombined_df.head()
# Out:
#             Delta  sentiment_score
# month
# 2018-08 -0.368791         0.704700
# 2018-10 -0.354458         0.254475
# 2018-11 -0.397576         0.444836
# 2018-12 -0.782243         0.456750
# 2019-01  0.232104         0.355733

# %%
#Reset the index
WellsFargoNewsCombined_df.reset_index(inplace=True)
WellsFargoNewsCombined_df
# Out:
#      month     Delta  sentiment_score
# 0  2018-08 -0.368791         0.704700
# 1  2018-10 -0.354458         0.254475
# 2  2018-11 -0.397576         0.444836
# 3  2018-12 -0.782243         0.456750
# 4  2019-01  0.232104         0.355733
# 5  2019-02  0.027244         0.272528
# 6  2019-03 -0.268889         0.193609
# 7  2019-04  0.110511         0.321199
# 8  2019-05  0.064634         0.387234
# 9  2019-06  0.154368         0.333171

# %%
#Import datetime
from datetime import datetime

#WellsFargoNewsCombined_df.month = pd.to_datetime(WellsFargoNewsCombined_df['month'])

# %%
#Convert date to have month be first
WellsFargoNewsCombined_df.month = WellsFargoNewsCombined_df.month.dt.strftime('%m/%Y')

# %%
#Plot line graph over a year's time showing stock change and sentiment score.
delta_month_WFC = WellsFargoNewsCombined_df['Delta']
score_month_WFC = WellsFargoNewsCombined_df['sentiment_score']
date = WellsFargoNewsCombined_df['month']

plt.plot(date,delta_month_WFC)
plt.plot(date,score_month_WFC)
plt.xticks(rotation=45)
plt.title("Wells Fargo: Sentiment Score vs Stock % Change")
plt.xlabel("Date")
plt.legend(['Stock % Change','Sentiment Score'])
plt.savefig("Wells Fargo: Sentiment Score vs Stock % Change Line.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for Wells Fargo Monthly News
WellsFargoMonthlyCorrelation = sp.pearsonr(delta_month_WFC,score_month_WFC)
print(f'The correlation between the delta and sentiment scores for Wells Fargo Monthly News \nis {WellsFargoMonthlyCorrelation[0]}, with a P value of {WellsFargoMonthlyCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for Wells Fargo Monthly News
# is -0.34725875837095904, with a P value of 0.32553659641719607

# %%
#Check Political News
PoliNews.head()
# Out:
#   datePublished                                        description  \
# 0    07/05/2019        Music, Film, TV and Political News Coverage
# 1    07/04/2019        Music, Film, TV and Political News Coverage
# 2    07/02/2019  Arguing an omnibus elections bill signed by Go...
# 3    07/01/2019  Gen Z's go-to source for political news is Ins...
# 4    06/28/2019  The Supreme Court will decide whether Presiden...
#
#                                         keywords           provider  \
# 0          rolling stone,political,music,film,tv       rollingstone
# 1          rolling stone,political,music,film,tv         hypervocal
# 2        florida political news,sunshine,lawsuit  sunshinestatenews
# 3  business insider india,political news,gen,ist    businessinsider
# 4          president donald trump,political news               wthr
#
#                                                title  \
# 0  Amazon Prime Day 2019: How to Get the Best Dea...
# 1  Why QAnon Is Obsessed With John F. Kennedy, Jr...
# 2        State Wants Ballot Signature Lawsuit Tossed
# 3  and it's already having an impact on the 2020 ...
# 4   Supreme Court to decide on Trump bid to end DACA
#
#                                                  url sentiment_score sentiment
# 0  https://www.rollingstone.com/culture/culture-n...               0  negative
# 1                http://hypervocal.com/items/2780760               0  negative
# 2  http://sunshinestatenews.com/story/state-wants...         -0.6369  negative
# 3  http://businessinsider.in/instagram-is-gen-zs-...               0  negative
# 4  https://www.wthr.com/article/supreme-court-dec...          0.5574  positive

# %%
# change data type of sentiment score to numeric
PoliNews.sentiment_score = pd.to_numeric(PoliNews.sentiment_score)

# change name of date column to match stock DF
PoliNews = PoliNews.rename(columns = {'datePublished':'Date'})

# %%
PoliNewsSummary = PoliNews.groupby('Date')['sentiment_score'].mean()
PoliNewsSummary.head()
# Out:
# Date
# 01/04/2001    0.0000
# 01/08/2019    0.0000
# 01/15/2014   -0.7430
# 01/15/2019   -0.8906
# 01/17/2014    0.1531
# Name: sentiment_score, dtype: float64

# %%
# Merge 2 dataframes on Date
PoliNewsCombined = pd.merge(stock_df,PoliNewsSummary, on = 'Date', how = 'inner')
PoliNewsCombined['Delta'] = (PoliNewsCombined.Close - PoliNewsCombined.Open)*100/PoliNewsCombined.Open
PoliNewsCombined
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0     Nasdaq  01/15/2019  6931.390137  7025.850098  6928.120117  7023.830078
# 1    S&P 500  01/15/2019  2585.100098  2613.080078  2585.100098  2610.300049
# 2     Nasdaq  01/22/2019  7109.569824  7110.160156  6979.810059  7020.359863
# 24   2467.419922  5585780000 -1.175523         0.401900
# 25   6528.410156  3258090000 -1.200855         0.401900
# 26   2700.060059  4499840000 -2.960357         0.273200
# 27   7158.430176  2635810000 -3.368273         0.273200
# 28   7414.620117  2124330000  0.757863         0.000000
# 29   2744.729980  3827770000  0.812451         0.000000
# ..           ...         ...       ...              ...
# 96   2924.919922  3122920000  0.180158         0.073733
# 97   7967.759766  2023120000  0.357710         0.073733
# 98   8006.240234  4078990000  0.218813         0.054314
# 99   2941.760010  5420700000  0.300725         0.054314
# 100  7333.020020  2576920000 -1.453929         0.000000
# 101  2744.449951  3943810000 -0.257314         0.000000
# 102  7527.120117  2369150000  1.526586         0.000000
# 103  2803.270020  3810430000  1.470699         0.000000
# 104  7575.479980  2115570000 -0.134466         0.000000
# 105  2826.149902  3548830000  0.286003         0.000000
# 106  7615.549805  2070940000  0.439310         0.000000
# 107  2843.489990  3396410000  0.529607         0.000000
# 108  2873.340088  3220250000  0.717522         0.310600
# 109  7742.100098  2066020000  1.164644         0.310600
# 110  2726.709961  3073650000  0.804451        -0.374100
# 111  7567.689941  1767910000  1.553832        -0.374100
# 112  7841.870117  1654290000  0.447550         0.202300
# 113  2806.979980  2907430000  0.279013         0.202300
# 114  8030.040039  1961300000 -0.111578         0.476700
# 115  2897.520020  2683190000 -0.135447         0.476700
# 116  2904.310059  3074610000  0.469432         0.000000
# 117  7956.109863  2317990000  0.664763         0.000000
# 118  2905.969971  3388620000 -0.377445        -0.195100
# 119  7990.370117  2297030000 -0.265987        -0.195100
# 120  8041.970215  2053770000  0.258689         0.202300
# 121  2914.000000  3060850000  0.080714         0.202300
# 122  8091.250000  2229520000  0.040799        -0.140500
# 123  2896.719971  3077060000 -0.008284        -0.140500
# 124  2878.050049  3139590000 -0.366603         0.000000
# 125  7922.729980  2368680000 -0.944455         0.000000
#
# [126 rows x 10 columns]

# %%
# Use Matplotlib and stats to generate graphs and look for relationships
#S&P Scatterplot
PoliNewsCombinedSP = PoliNewsCombined.loc[(PoliNewsCombined["Index"] == "S&P 500")]
Polisentiment_score_SP = PoliNewsCombinedSP['sentiment_score']
Polidelta_SP = PoliNewsCombinedSP['Delta']


plt.title("Political News S&P 500: Sentiment Score vs Stock Change %")
plt.xlabel("Stock Price")
plt.ylabel("Sentiment Score")

plt.scatter(Polidelta_SP, Polisentiment_score_SP , marker="o", facecolors="red", edgecolors="black",
            alpha=0.75)
plt.savefig("Political News S&P 500: Sentiment Score vs Stock Change % Scat.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for Political News & S&P 500
PoliNewsSPCorrelation = sp.pearsonr(Polidelta_SP,Polisentiment_score_SP)
print(f'The correlation between the delta and sentiment scores for Political News and the S&P 500 \nis {PoliNewsSPCorrelation[0]}, with a P value of {PoliNewsSPCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for Political News and the S&P 500
# is -0.041178514734699564, with a P value of 0.7486384166889715

# %%
PoliNewsCombinedNSQ = PoliNewsCombined.loc[(PoliNewsCombined["Index"] == "Nasdaq")]
Polisentiment_score_NSQ = PoliNewsCombinedNSQ['sentiment_score']
Polidelta_NSQ = PoliNewsCombinedNSQ['Delta']


plt.title("Political News Nasdaq: Sentiment Score vs Stock Change %")
plt.xlabel("Stock Price")
plt.ylabel("Sentiment Score")

plt.scatter(Polidelta_NSQ, Polisentiment_score_NSQ, marker="o", facecolors="red", edgecolors="black",
            alpha=0.75)
plt.savefig("Political News Nasdaq: Sentiment Score vs Stock Change % Scat.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for Political News & Nasdaq
PoliNewsSPCorrelation = sp.pearsonr(Polidelta_NSQ,Polisentiment_score_NSQ)
print(f'The correlation between the delta and sentiment scores for Political News and the S&P 500 \nis {PoliNewsSPCorrelation[0]}, with a P value of {PoliNewsSPCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for Political News and the S&P 500
# is -0.13248077656844123, with a P value of 0.30064671700933465

# %%
#Convert and add a new column to show only the month
PoliNewsCombined['Date'] = pd.to_datetime(PoliNewsCombined['Date'])
PoliNewsCombined['month'] = PoliNewsCombined['Date'].dt.to_period('M')
PoliNewsCombined.head()
# Out:
#      Index       Date         Open         High          Low        Close  \
# 0   Nasdaq 2019-01-15  6931.390137  7025.850098  6928.120117  7023.830078
# 1  S&P 500 2019-01-15  2585.100098  2613.080078  2585.100098  2610.300049
# 2   Nasdaq 2019-01-22  7109.569824  7110.160156  6979.810059  7020.359863
# 3  S&P 500 2019-01-22  2657.879883  2657.879883  2617.270020  2632.899902
# 4   Nasdaq 2019-01-08  6893.439941  6909.580078  6795.859863  6897.000000
#
#      Adj Close      Volume     Delta  sentiment_score    month
# 0  7023.830078  2038090000  1.333642          -0.8906  2019-01
# 1  2610.300049  3572330000  0.974815          -0.8906  2019-01
# 2  7020.359863  2380950000 -1.254787          -0.7096  2019-01
# 3  2632.899902  3908030000 -0.939846          -0.7096  2019-01
# 4  6897.000000  2380290000  0.051644           0.0000  2019-01

# %%
#Create new dataframe to group by month
PoliNewsCombinedMonth = PoliNewsCombined.groupby('month')["Delta"].mean()
PoliNewsCombined_df = pd.DataFrame(PoliNewsCombinedMonth)
PoliNewsCombined_df['sentiment_score'] = PoliNewsCombined.groupby('month')['sentiment_score'].mean()
PoliNewsCombined_df.head()
# Out:
#             Delta  sentiment_score
# month
# 2018-07  0.771212         -0.08590
# 2018-08 -0.123512          0.47670
# 2018-09 -0.044838         -0.02666
# 2018-10  0.126714          0.16992
# 2018-11  0.952725          0.31845

# %%
#Reset the index
PoliNewsCombined_df.reset_index(inplace=True)
PoliNewsCombined_df
# Out:
#       month     Delta  sentiment_score
# 0   2018-07  0.771212        -0.085900
# 1   2018-08 -0.123512         0.476700
# 2   2018-09 -0.044838        -0.026660
# 3   2018-10  0.126714         0.169920
# 4   2018-11  0.952725         0.318450
# 5   2018-12 -1.490213         0.188950
# 6   2019-01  0.068463        -0.533400
# 7   2019-02  0.396078         0.000000
# 8   2019-03  0.149799         0.000000
# 9   2019-04  0.057145         0.017200
# 10  2019-05  0.120679        -0.014677
# 11  2019-06  0.042258         0.034202

# %%
#Convert date to have month be first
PoliNewsCombined_df.month = PoliNewsCombined_df.month.dt.strftime('%m/%Y')

# %%
#Plot line graph over a year's time showing stock change and sentiment score.
delta_month_P = PoliNewsCombined_df['Delta']
score_month_P = PoliNewsCombined_df['sentiment_score']
date = PoliNewsCombined_df['month']

plt.plot(date,delta_month_P)
plt.plot(date,score_month_P)
plt.xticks(rotation=45)
plt.title("Political News: Stock % Change vs S. Score")
plt.xlabel("Date")
plt.legend(['Stock % Change','Sentiment Score'])
plt.savefig("Political News: Stock % Change vs S. Score Line.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for Political News & Nasdaq
PoliNewsSumCorrelation = sp.pearsonr(delta_month_P,score_month_P)
print(f'The correlation between the delta and sentiment scores for Political News and the S&P 500 by month \nis {PoliNewsSumCorrelation[0]}, with a P value of {PoliNewsSumCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for Political News and the S&P 500 by month
# is -0.10177243015219975, with a P value of 0.7529711603805183

# %%
FinNews.head()
# Out:
#   datePublished                                        description  \
# 0    07/05/2019  The "Futures Now" team discusses the gold mark...
# 1    07/03/2019  Lagarde has never seemed interested by the fie...
# 2    06/29/2019  MarketWatch provides the latest stock market, ...
# 3    06/26/2019  Business Standard, India's leading business si...
# 4    06/20/2019  THE BUSINESS TIMES - Find latest business & fi...
#
#                                             keywords           provider  \
# 0               financial news,stock quotes,business               cnbc
# 1  lagarde appointment risks,s s making the ecb,f...           fnlondon
# 2  stock market news,financial news,marketwatch,send        marketwatch
# 3          financial news,business news,stock market  business-standard
# 4         business times,financial news,videos,house      businesstimes
#
#                                                title  \
# 0                   Futures Now: Gold feels the heat
# 1  Christine Lagarde appointment risks making the...
# 2                     MarketWatch: Stock Market News
# 3  India News, Latest News Headlines, BSE live, N...
# 4           Get the Latest Business & Financial News
#
#                                                  url sentiment_score sentiment
# 0  https://www.cnbc.com/video/2019/07/05/futures-...               0  negative
# 1  https://www.fnlondon.com/articles/christine-la...         -0.8425  negative
# 2  https://www.marketwatch.com?mod=side_nav/inves...               0  negative
# 3  http://business-standard.com/companies-results...               0  negative
# 4            http://businesstimes.com.sg/atom/174420          0.2023  positive

# %%
# change data type of sentiment score to numeric
FinNews.sentiment_score = pd.to_numeric(FinNews.sentiment_score)

# change name of date column to match stock DF
FinNews = FinNews.rename(columns = {'datePublished':'Date'})

# %%
FinNewsSummary = FinNews.groupby('Date')['sentiment_score'].mean()
FinNewsSummary.head()
# Out:
# Date
# 01/09/2019    0.2960
# 01/11/2019    0.0000
# 01/12/2019    0.0000
# 01/14/2019    0.0000
# 01/15/2019    0.0114
# Name: sentiment_score, dtype: float64

# %%
# Merge 2 dataframes on Date
FinNewsCombined = pd.merge(stock_df,FinNewsSummary, on = 'Date', how = 'inner')
FinNewsCombined['Delta'] = (FinNewsCombined.Close - FinNewsCombined.Open)*100/FinNewsCombined.Open
FinNewsCombined
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0    S&P 500  01/11/2019  2588.110107  2596.270020  2577.399902  2596.260010
# 1     Nasdaq  01/11/2019  6947.459961  6975.649902  6933.600098  6971.479980
# 2     Nasdaq  01/14/2019  6908.029785  6936.220215  6887.479980  6905.919922
# 3    S&P 500  01/14/2019  2580.310059  2589.320068  2570.409912  2582.610107
# 4     Nasdaq  01/15/2019  6931.390137  7025.850098  6928.120117  7023.830078
# 5    S&P 500  01/15/2019  2585.100098  2613.080078  2585.100098  2610.300049
# 6     Nasdaq  01/16/2019  7033.750000  7079.629883  7028.120117  7034.689941
# 7    S&P 500  01/16/2019  2614.750000  2625.760010  2612.679932  2616.100098
# 8     Nasdaq  01/17/2019  7010.129883  7113.950195  7003.620117  7084.459961
# 9    S&P 500  01/17/2019  2609.280029  2645.060059  2606.360107  2635.959961
# 173  2803.270020  3810430000  1.470699         0.016419
# 174  7575.479980  2115570000 -0.134466         0.160283
# 175  2826.149902  3548830000  0.286003         0.160283
# 176  7615.549805  2070940000  0.439310         0.111443
# 177  2843.489990  3396410000  0.529607         0.111443
# 178  2873.340088  3220250000  0.717522        -0.006889
# 179  7742.100098  2066020000  1.164644        -0.006889
# 180  2798.429932  2812230000  0.038244         0.757900
# 181  7805.720215  1730190000 -0.332238         0.757900
# 182  7819.709961  1914240000 -0.360475         0.729400
# 183  2821.929932  3158450000 -0.477172         0.729400
# 184  7878.459961  1879890000 -0.101570         0.601000
# 185  2856.979980  2713910000 -0.115725         0.601000
# 186  7945.979980  1886600000  0.482686         0.000000
# 187  2874.689941  2596190000  0.431109         0.000000
# 188  7812.009766  2018700000 -0.092339         0.000000
# 189  2840.350098  3030390000  0.379202         0.000000
# 190  7954.229980  2341850000 -0.058301         0.000000
# 191  2888.919922  3264930000  0.021808         0.000000
# 192  8041.970215  2053770000  0.258689         0.526700
# 193  2914.000000  3060850000  0.080714         0.526700
# 194  8046.350098  2323940000  0.272292         0.102700
# 195  2913.979980  3432300000  0.135736         0.102700
# 196  2888.600098  3241250000 -0.103403         0.296000
# 197  7995.169922  2596780000 -0.970577         0.296000
#
# [198 rows x 10 columns]

# %%
# Use Matplotlib and stats to generate graphs and look for relationships
#S&P Scatterplot
FinNewsCombinedSP = FinNewsCombined.loc[(FinNewsCombined["Index"] == "S&P 500")]
Finsentiment_score_SP = FinNewsCombinedSP['sentiment_score']
Findelta_SP = FinNewsCombinedSP['Delta']


plt.title("Financial News - S&P 500: Sentiment Score vs Stock Change %")
plt.xlabel("Stock Price")
plt.ylabel("Sentiment Score")

plt.scatter(Findelta_SP, Finsentiment_score_SP , marker="o", facecolors="red", edgecolors="black",
            alpha=0.75)
plt.savefig("FinNews - S&P 500: Sentiment Score vs Stock Change % Scat.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for Financial News & S&P 500
FinNewsSumCorrelation = sp.pearsonr(Findelta_SP,Finsentiment_score_SP)
print(f'The correlation between the delta and sentiment scores for Financial News and the S&P 500 \nis {FinNewsSumCorrelation[0]}, with a P value of {FinNewsSumCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for Financial News and the S&P 500
# is 0.028993001692546944, with a P value of 0.7757415224649782

# %%
# Use Matplotlib and stats to generate graphs and look for relationships
#S&P Scatterplot
FinNewsCombinedNSQ = FinNewsCombined.loc[(FinNewsCombined["Index"] == "Nasdaq")]
Finsentiment_score_NSQ = FinNewsCombinedNSQ['sentiment_score']
Findelta_NSQ = FinNewsCombinedNSQ['Delta']


plt.title("Financial News - Nasdaq: Sentiment Score vs Stock Change %")
plt.xlabel("Stock Price")
plt.ylabel("Sentiment Score")

plt.scatter(Polidelta_NSQ, Polisentiment_score_NSQ , marker="o", facecolors="red", edgecolors="black",
            alpha=0.75)
plt.savefig("FinNews - Nasdaq: Sentiment Score vs Stock Change % Scat.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for Financial News & Nasdaq
FinNewsNSQCorrelation = sp.pearsonr(Findelta_NSQ,Finsentiment_score_NSQ)
print(f'The correlation between the delta and sentiment scores for Financial News and the Nasdaq \nis {FinNewsNSQCorrelation[0]}, with a P value of {FinNewsNSQCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for Financial News and the Nasdaq
# is 0.08068918367301078, with a P value of 0.4272264847780394

# %%
#Convert and add a new column to show only the month
FinNewsCombined['Date'] = pd.to_datetime(FinNewsCombined['Date'])
FinNewsCombined['month'] = FinNewsCombined['Date'].dt.to_period('M')
FinNewsCombined.head()
# Out:
#      Index       Date         Open         High          Low        Close  \
# 0  S&P 500 2019-01-11  2588.110107  2596.270020  2577.399902  2596.260010
# 1   Nasdaq 2019-01-11  6947.459961  6975.649902  6933.600098  6971.479980
# 2   Nasdaq 2019-01-14  6908.029785  6936.220215  6887.479980  6905.919922
# 3  S&P 500 2019-01-14  2580.310059  2589.320068  2570.409912  2582.610107
# 4   Nasdaq 2019-01-15  6931.390137  7025.850098  6928.120117  7023.830078
#
#      Adj Close      Volume     Delta  sentiment_score    month
# 0  2596.260010  3434490000  0.314898           0.0000  2019-01
# 1  6971.479980  2066500000  0.345738           0.0000  2019-01
# 2  6905.919922  1942210000 -0.030542           0.0000  2019-01
# 3  2582.610107  3664450000  0.089138           0.0000  2019-01
# 4  7023.830078  2038090000  1.333642           0.0114  2019-01

# %%
#Create new dataframe to group by month
FinNewsCombinedMonth = FinNewsCombined.groupby('month')["Delta"].mean()
FinNewsCombined_df = pd.DataFrame(FinNewsCombinedMonth)
FinNewsCombined_df['sentiment_score'] = FinNewsCombined.groupby('month')['sentiment_score'].mean()
FinNewsCombined_df.head()
# Out:
#             Delta  sentiment_score
# month
# 2018-06 -0.384819         0.137200
# 2018-07 -0.146997         0.757900
# 2018-08  0.018215         0.332600
# 2018-09 -0.045380         0.231350
# 2018-12 -0.445042         0.162742

# %%
#Reset the index
FinNewsCombined_df.reset_index(inplace=True)
FinNewsCombined_df
# Out:
#       month     Delta  sentiment_score
# 0   2018-06 -0.384819         0.137200
# 1   2018-07 -0.146997         0.757900
# 2   2018-08  0.018215         0.332600
# 3   2018-09 -0.045380         0.231350
# 4   2018-12 -0.445042         0.162742
# 5   2019-01  0.150645        -0.110960
# 6   2019-02  0.148867         0.056750
# 7   2019-03 -0.026793         0.037663
# 8   2019-04  0.084189         0.063749
# 9   2019-05  0.035704         0.075866
# 10  2019-06  0.036912         0.080068

# %%
FinNewsCombined_df.month = FinNewsCombined_df.month.dt.strftime('%m/%Y')

# %%
#Plot line graph over a year's time showing stock change and sentiment score.
delta_month_F = FinNewsCombined_df['Delta']
score_month_F = FinNewsCombined_df['sentiment_score']
date = FinNewsCombined_df['month']

plt.plot(date,delta_month_F)
plt.plot(date,score_month_F)
plt.xticks(rotation=45)
plt.title("Financial News: Sentiment Score vs Stock % Change")
plt.xlabel("Date")
plt.legend(['Stock % Change','Sentiment Score'])
plt.savefig("Financial News: Sentiment Score vs Stock % Change Line.png")
plt.show()

# %%
# find correlation coefficient between Delta and sentiment_score column for Financial News & Sentiment Score
FinNewsSumCorrelation = sp.pearsonr(delta_month_F,score_month_F)
print(f'The correlation between the delta and sentiment scores for Financial News and general Sentiment \nis {FinNewsSumCorrelation[0]}, with a P value of {FinNewsSumCorrelation[1]}')
# Out:
# The correlation between the delta and sentiment scores for Financial News and general Sentiment
# is -0.3193318711579122, with a P value of 0.3384573766313927
